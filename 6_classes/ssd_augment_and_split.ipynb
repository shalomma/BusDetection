# %%
from preprocess_images import *
import pandas as pd
import numpy as np
import os
import glob
import random
import cv2 as cv
import imgaug as ia
from imgaug import augmenters as iaa

# %%
# This is needed to display the images.
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (9, 9)

# %%
# original images
PATH = os.getcwd()
PATH_TO_ANNO = 'annotations/'
ANNO_TABLE = 'BusAnnotation.csv'
PATH_TO_IMAGES = 'images/originals/'
PATH_TO_RESIZED_IMAGES = 'images/resized/'
# augmented images
PATH_TO_AUG_IMAGES = 'aug_images/'

# %%
df = pd.read_csv(os.path.join(PATH_TO_ANNO, ANNO_TABLE))

# %%
df.head(8)
# Out:
#        filename  width  height  class  xmin  ymin  xmax  ymax
# 0  DSCF1013.JPG   3648    2736      1  1217  1690  1706  1891
# 1  DSCF1013.JPG   3648    2736      2  1774  1619  2249  1843
# 2  DSCF1013.JPG   3648    2736      3  2313  1566  2773  1794
# 3  DSCF1013.JPG   3648    2736      4  1284  1832  1781  2063
# 4  DSCF1013.JPG   3648    2736      5  1879  1798  2365  2026
# 5  DSCF1013.JPG   3648    2736      6  2429  1742  2904  1970
# 6  DSCF1015.JPG   3648    2736      3   641  1342  1822  2234
# 7  DSCF1015.JPG   3648    2736      6  2053  1022  3175  1757

# %%
imresize_to_300x225(PATH_TO_IMAGES, PATH_TO_RESIZED_IMAGES, df=df)

# %%
# new scaled df
df.head(8)
# Out:
#          filename  width  height  class  xmin  ymin  xmax  ymax
# 0  s_DSCF1013.JPG    300     225      1   100   138   140   155
# 1  s_DSCF1013.JPG    300     225      2   145   133   184   151
# 2  s_DSCF1013.JPG    300     225      3   190   128   228   147
# 3  s_DSCF1013.JPG    300     225      4   105   150   146   169
# 4  s_DSCF1013.JPG    300     225      5   154   147   194   166
# 5  s_DSCF1013.JPG    300     225      6   199   143   238   162
# 6  s_DSCF1015.JPG    300     225      3    52   110   149   183
# 7  s_DSCF1015.JPG    300     225      6   168    84   261   144

# %%
# save resized anno table
df.to_csv(os.path.join(PATH_TO_ANNO, 'bus_anno_resized.csv'), index=False)

# %%
[filenames, images, bboxes, classes] = get_images_bboxes(df=df, path_to_images=PATH_TO_RESIZED_IMAGES)

# %%
imshow_bbox(images, bboxes, 4)

# %%
df.head(10)
# Out:
#          filename  width  height  class  xmin  ymin  xmax  ymax
# 0  s_DSCF1013.JPG    300     225      1   100   138   140   155
# 1  s_DSCF1013.JPG    300     225      2   145   133   184   151
# 2  s_DSCF1013.JPG    300     225      3   190   128   228   147
# 3  s_DSCF1013.JPG    300     225      4   105   150   146   169
# 4  s_DSCF1013.JPG    300     225      5   154   147   194   166
# 5  s_DSCF1013.JPG    300     225      6   199   143   238   162
# 6  s_DSCF1015.JPG    300     225      3    52   110   149   183
# 7  s_DSCF1015.JPG    300     225      6   168    84   261   144
# 8  s_DSCF1016.JPG    300     225      4    87   151   179   201
# 9  s_DSCF1016.JPG    300     225      6   160   105   244   151

# %%
sometimes08 = lambda aug: iaa.Sometimes(0.8, aug)
sometimes05 = lambda aug: iaa.Sometimes(0.5, aug)

def seq_det_aug():
    seq = iaa.Sequential([iaa.Multiply(mul=(0.75, 1.25)),
                          iaa.Add(value=(-40, 40)),
                          iaa.Fliplr(0.5),
                          
                          sometimes08(iaa.OneOf([iaa.CoarseDropout((0.01, 0.1), size_percent=(0.02, 0.05)),
                                                 iaa.GaussianBlur(sigma=(0.0, 1.0))])),

                          sometimes08(iaa.OneOf([iaa.Grayscale(alpha=(0.0, 0.1)),
                                                 iaa.ContrastNormalization((0.8, 1.2)),
                                                 iaa.Superpixels(p_replace=0.1, n_segments=1024)])),
                          
                          sometimes05(iaa.OneOf([iaa.AdditiveGaussianNoise(scale=(0, 0.01*255)),
                                                 iaa.AverageBlur(k=((1, 3), (1, 3))),
                                                 iaa.AddElementwise((-10, 10)),
                                                 iaa.Sharpen(alpha=(0.2, 0.8), lightness=(0.75, 1.5))])),
                                                    
                          sometimes08(iaa.Affine(
                                    scale=(0.7, 1.3), # scale images to 80-120% of their size, individually per axis
                                    translate_percent=(-0.2, 0.2), # translate by -20 to +20 percent (per axis)
                                    rotate=(-15, 15),
                                    shear=(-12, 12),
                                    order=3, # interpolation
                                    cval=[100,200])) # if mode is constant, use cval 0
                         ])
    seq_det = seq.to_deterministic() # call this for each batch again, NOT only once at the start
    return seq_det

# %%
batches_to_concat = []
batch = 100
for i in range(batch):
    if (i == 0):
        seq = iaa.Noop()
    else:
        seq = seq_det_aug()
        
    images_aug = seq.augment_images(images)
    bboxes_aug = seq.augment_bounding_boxes(bboxes)
    filename_aug_batch = [str(i).zfill(2) + '_' + f for f in filenames]
    df_batch = imwrite_aug_ssd(images_aug, filename_aug_batch, bboxes_aug,
                               classes, os.path.join(PATH, PATH_TO_AUG_IMAGES))
    batches_to_concat.append(df_batch.copy())
#     imshow_bbox(images_aug, bboxes_aug, 2)

df_aug = pd.concat(batches_to_concat)
df_aug.to_csv(os.path.join(PATH_TO_ANNO, 'bus_anno_aug.csv'), index=None)

# %%
print('Num of objects in the training set:', len(df_aug['filename'].tolist()))
print('Num of images in the training set:', len(list(set(df_aug['filename'].tolist()))))
# Out:
# Num of objects in the training set: 10396
# Num of images in the training set: 6000

# %%
# test augmentation
[_, img_t, bb_t, _] = get_images_bboxes(df=df_aug, path_to_images=PATH_TO_AUG_IMAGES)
imshow_bbox(img_t, bb_t, 10)

# %%
# split the data to tarin (90%) and test (10%) sets
original_images = glob.glob(PATH_TO_IMAGES + '*.JPG')
original_images = list(map(lambda s: s[-8:-4], original_images))

# %%
to_test_images = np.random.choice(original_images, size=6)
print('images to test set: {}'.format(to_test_images))
# Out:
# images to test set: ['1025' '1133' '1015' '1120' '1070' '1099']

# %%
df_aug = pd.read_csv(os.path.join(PATH_TO_ANNO, 'bus_anno_aug.csv'))

# %%
df_aug_test = df_aug[df_aug.apply(lambda x: x['filename'][-8:-4] in to_test_images, axis=1)]

# %%
df_aug_train = df_aug[df_aug.apply(lambda x: x['filename'][-8:-4] not in to_test_images, axis=1)]

# %%
df_aug_train.to_csv(os.path.join(PATH_TO_ANNO, 'bus_anno_aug_train_fold4.csv'), index=False)
df_aug_test.to_csv(os.path.join(PATH_TO_ANNO, 'bus_anno_aug_test_fold4.csv'), index=False)

# %%
# review part of the train set 
df_aug_train[df_aug_train.apply(lambda x: x['filename'][-8:-4] == '1013', axis=1)]
# Out:
#                 filename  width  height  class  xmin  ymin  xmax  ymax  \
# 13     00_s_DSCF1013.JPG    300     225      1   100   138   140   155
# 14     00_s_DSCF1013.JPG    300     225      2   145   133   184   151
# 15     00_s_DSCF1013.JPG    300     225      3   190   128   228   147
# 16     00_s_DSCF1013.JPG    300     225      4   105   150   146   169
# 17     00_s_DSCF1013.JPG    300     225      5   154   147   194   166
# 18     00_s_DSCF1013.JPG    300     225      6   199   143   238   162
# 117    01_s_DSCF1013.JPG    300     225      1   123   151   167   175
# 118    01_s_DSCF1013.JPG    300     225      2   171   152   214   177
# 119    01_s_DSCF1013.JPG    300     225      3   219   153   261   180
# 120    01_s_DSCF1013.JPG    300     225      4   129   165   174   191
# 121    01_s_DSCF1013.JPG    300     225      5   182   169   226   195
# 122    01_s_DSCF1013.JPG    300     225      6   230   171   273   197
# 221    02_s_DSCF1013.JPG    300     225      1   167   180   206   201
# 222    02_s_DSCF1013.JPG    300     225      2   207   170   244   191
# 223    02_s_DSCF1013.JPG    300     225      3   246   159   283   181
# 224    02_s_DSCF1013.JPG    300     225      4   174   190   213   213
# 225    02_s_DSCF1013.JPG    300     225      5   217   181   256   203
# 226    02_s_DSCF1013.JPG    300     225      6   257   171   294   194
# 325    03_s_DSCF1013.JPG    300     225      1   100   138   140   155
# 326    03_s_DSCF1013.JPG    300     225      2   145   133   184   151
# 327    03_s_DSCF1013.JPG    300     225      3   190   128   228   147
# 328    03_s_DSCF1013.JPG    300     225      4   105   150   146   169
# 329    03_s_DSCF1013.JPG    300     225      5   154   147   194   166
# 330    03_s_DSCF1013.JPG    300     225      6   199   143   238   162
# 429    04_s_DSCF1013.JPG    300     225      1   105   100   142   116
# 430    04_s_DSCF1013.JPG    300     225      2    68    95   104   111
# 431    04_s_DSCF1013.JPG    300     225      3    31    89    67   106
# 432    04_s_DSCF1013.JPG    300     225      4    98   110   136   127
# 433    04_s_DSCF1013.JPG    300     225      5    57   106    94   123
# 434    04_s_DSCF1013.JPG    300     225      6    20   102    57   119
# ...                  ...    ...     ...    ...   ...   ...   ...   ...
# 9890   95_s_DSCF1013.JPG    300     225      1   100   138   140   155
# 9891   95_s_DSCF1013.JPG    300     225      2   145   133   184   151
# 9892   95_s_DSCF1013.JPG    300     225      3   190   128   228   147
# 9893   95_s_DSCF1013.JPG    300     225      4   105   150   146   169
# 9894   95_s_DSCF1013.JPG    300     225      5   154   147   194   166
# 9895   95_s_DSCF1013.JPG    300     225      6   199   143   238   162
# 9994   96_s_DSCF1013.JPG    300     225      1   107   146   162   174
# 9995   96_s_DSCF1013.JPG    300     225      2   158   131   213   160
# 9996   96_s_DSCF1013.JPG    300     225      3   210   116   263   146
# 9997   96_s_DSCF1013.JPG    300     225      4   118   159   175   189
# 9998   96_s_DSCF1013.JPG    300     225      5   175   145   231   175
# 9999   96_s_DSCF1013.JPG    300     225      6   227   131   282   161
# 10098  97_s_DSCF1013.JPG    300     225      1   131   154   171   173
# 10099  97_s_DSCF1013.JPG    300     225      2   172   144   211   165
# 10100  97_s_DSCF1013.JPG    300     225      3   212   135   250   156
# 10101  97_s_DSCF1013.JPG    300     225      4   138   164   180   185
# 10102  97_s_DSCF1013.JPG    300     225      5   183   156   223   177
# 10103  97_s_DSCF1013.JPG    300     225      6   223   147   263   169
# 10202  98_s_DSCF1013.JPG    300     225      1   159   138   199   155
# 10203  98_s_DSCF1013.JPG    300     225      2   115   133   154   151
# 10204  98_s_DSCF1013.JPG    300     225      3    71   128   109   147
# 10205  98_s_DSCF1013.JPG    300     225      4   153   150   194   169
# 10206  98_s_DSCF1013.JPG    300     225      5   105   147   145   166
# 10207  98_s_DSCF1013.JPG    300     225      6    61   143   100   162
# 10305  99_s_DSCF1013.JPG    300     225      1   205   167   253   194
# 10306  99_s_DSCF1013.JPG    300     225      2   153   169   200   197
# 10307  99_s_DSCF1013.JPG    300     225      3   101   171   147   201
# 10308  99_s_DSCF1013.JPG    300     225      4   199   182   248   212
# 10309  99_s_DSCF1013.JPG    300     225      5   143   187   191   217
# 10310  99_s_DSCF1013.JPG    300     225      6    91   191   138   220
#
#                                                     path
# 13     /home/sha_maayan/busProject/6_classes/augmenta...
# 14     /home/sha_maayan/busProject/6_classes/augmenta...
# 15     /home/sha_maayan/busProject/6_classes/augmenta...
# 16     /home/sha_maayan/busProject/6_classes/augmenta...
# 17     /home/sha_maayan/busProject/6_classes/augmenta...
# 18     /home/sha_maayan/busProject/6_classes/augmenta...
# 117    /home/sha_maayan/busProject/6_classes/augmenta...
# 118    /home/sha_maayan/busProject/6_classes/augmenta...
# 119    /home/sha_maayan/busProject/6_classes/augmenta...
# 120    /home/sha_maayan/busProject/6_classes/augmenta...
# 121    /home/sha_maayan/busProject/6_classes/augmenta...
# 122    /home/sha_maayan/busProject/6_classes/augmenta...
# 221    /home/sha_maayan/busProject/6_classes/augmenta...
# 222    /home/sha_maayan/busProject/6_classes/augmenta...
# 223    /home/sha_maayan/busProject/6_classes/augmenta...
# 224    /home/sha_maayan/busProject/6_classes/augmenta...
# 225    /home/sha_maayan/busProject/6_classes/augmenta...
# 226    /home/sha_maayan/busProject/6_classes/augmenta...
# 325    /home/sha_maayan/busProject/6_classes/augmenta...
# 326    /home/sha_maayan/busProject/6_classes/augmenta...
# 327    /home/sha_maayan/busProject/6_classes/augmenta...
# 328    /home/sha_maayan/busProject/6_classes/augmenta...
# 329    /home/sha_maayan/busProject/6_classes/augmenta...
# 330    /home/sha_maayan/busProject/6_classes/augmenta...
# 429    /home/sha_maayan/busProject/6_classes/augmenta...
# 430    /home/sha_maayan/busProject/6_classes/augmenta...
# 431    /home/sha_maayan/busProject/6_classes/augmenta...
# 432    /home/sha_maayan/busProject/6_classes/augmenta...
# 433    /home/sha_maayan/busProject/6_classes/augmenta...
# 434    /home/sha_maayan/busProject/6_classes/augmenta...
# ...                                                  ...
# 9890   /home/sha_maayan/busProject/6_classes/augmenta...
# 9891   /home/sha_maayan/busProject/6_classes/augmenta...
# 9892   /home/sha_maayan/busProject/6_classes/augmenta...
# 9893   /home/sha_maayan/busProject/6_classes/augmenta...
# 9894   /home/sha_maayan/busProject/6_classes/augmenta...
# 9895   /home/sha_maayan/busProject/6_classes/augmenta...
# 9994   /home/sha_maayan/busProject/6_classes/augmenta...
# 9995   /home/sha_maayan/busProject/6_classes/augmenta...
# 9996   /home/sha_maayan/busProject/6_classes/augmenta...
# 9997   /home/sha_maayan/busProject/6_classes/augmenta...
# 9998   /home/sha_maayan/busProject/6_classes/augmenta...
# 9999   /home/sha_maayan/busProject/6_classes/augmenta...
# 10098  /home/sha_maayan/busProject/6_classes/augmenta...
# 10099  /home/sha_maayan/busProject/6_classes/augmenta...
# 10100  /home/sha_maayan/busProject/6_classes/augmenta...
# 10101  /home/sha_maayan/busProject/6_classes/augmenta...
# 10102  /home/sha_maayan/busProject/6_classes/augmenta...
# 10103  /home/sha_maayan/busProject/6_classes/augmenta...
# 10202  /home/sha_maayan/busProject/6_classes/augmenta...
# 10203  /home/sha_maayan/busProject/6_classes/augmenta...
# 10204  /home/sha_maayan/busProject/6_classes/augmenta...
# 10205  /home/sha_maayan/busProject/6_classes/augmenta...
# 10206  /home/sha_maayan/busProject/6_classes/augmenta...
# 10207  /home/sha_maayan/busProject/6_classes/augmenta...
# 10305  /home/sha_maayan/busProject/6_classes/augmenta...
# 10306  /home/sha_maayan/busProject/6_classes/augmenta...
# 10307  /home/sha_maayan/busProject/6_classes/augmenta...
# 10308  /home/sha_maayan/busProject/6_classes/augmenta...
# 10309  /home/sha_maayan/busProject/6_classes/augmenta...
# 10310  /home/sha_maayan/busProject/6_classes/augmenta...
#
# [600 rows x 9 columns]
